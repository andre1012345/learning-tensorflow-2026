# %% [markdown]
# <a href="https://colab.research.google.com/github/andre1012345/learning-tensorflow-2026/blob/main/02_sequential_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Clone your repository
# !git clone https://github.com/andre1012345/learning-tensorflow-2026.git

# 2. Move inside the repository folder so your paths (data/...) work
# %cd learning-tensorflow-2026
# Out:
# Cloning into 'learning-tensorflow-2026'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 24 (delta 4), reused 23 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 21.20 KiB | 10.60 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/learning-tensorflow-2026/learning-tensorflow-2026/learning-tensorflow-2026/learning-tensorflow-2026

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# load data for the model

# %%
train_samples = np.load('data/train_samples.npy')
train_labels = np.load('data/train_Labels.npy')

# %% [markdown]
# Defining a proper model (simple data so easy model...notice I am not acting to modify the 1st layer with the first instruction but directly the second layer) of course the last layer should classify the point given so I have just 2 neurons

# %%
model = Sequential([
    Dense(units=16, input_shape=(1,), activation='relu'),
    Dense(units=32, activation='relu'), # Changed sigmoid to relu (standard for hidden layers)
    Dense(units=2, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │            32 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 642 (2.51 KB)
#  Trainable params: 642 (2.51 KB)
#  Non-trainable params: 0 (0.00 B)
